# %%
from platform import python_version
import pandas as pd
import numpy as np
from skbio.stats.composition import clr
import skbio
import re

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
print('The python version is {}.'.format(python_version()))
print('The pandas version is {}.'.format(pd.__version__))
print('The numpy version is {}.'.format(np.__version__))
print('The skbio version is {}.'.format(skbio.__version__))
# Out:
# The python version is 3.11.12.
# The pandas version is 2.1.3.
# The numpy version is 1.26.4.
# The skbio version is 0.6.2.

# %% [markdown]
# loading microbiome abundance table

# %%
genus=pd.read_csv( "genus.csv",index_col=0)
genus
# Out:
#                Lysinibacillus   Fusobacterium   Bacteroides   Prevotella  \
# SampleID
# ERR475500              232186               0          2651           11
# Cancer7-2537                0          214716         13442           16
# ERR475501                  42               0        180089           25
# ERR475507                   0               0         65835       151518
# ERR475506                   0               0          1024          164
# ...                       ...             ...           ...          ...
# SRR2143774                  0               0           528            0
# SRR2143541                  0               0          1257            0
# SRR2143550                  0               0          1253         1059
# SRR2143990                  0               0           312            0
# SRR2143628                  0               0           615            0
#
#                Sphingomonas   Blautia   Faecalibacterium  \
# SampleID
# ERR475500              8991       736                242
# Cancer7-2537              0     23077                 37
# ERR475501             36718      4312               1124
# ERR475507             16385      4057              52951
# ERR475506            144878    129257                340
# ...                     ...       ...                ...
# SRR2143774                0       999                202
# SRR2143541                0       495                141
# SRR2143550                0       240                238
# SRR2143990                0       548                 17
# SRR2143628                0       525                 48
#
#                [Eubacterium]_coprostanoligenes_group   Akkermansia  \
# SampleID
# ERR475500                                       3262         52978
# Cancer7-2537                                      64           533
# ERR475501                                         16             0
# ERR475507                                       1353          6781
# ERR475506                                       4787             0
# ...                                              ...           ...
# SRR2143774                                        13           837
# SRR2143541                                       122             0
# SRR2143550                                        73             0
# SRR2143990                                       215           393
# SRR2143628                                       101            74
#
#                Lachnoclostridium  ...   Acidibacter   Fimbriiglobus  \
# SampleID                          ...
# ERR475500                    961  ...             0               0
# Cancer7-2537                2908  ...             0               0
# ERR475501                  70389  ...             0               0
# ERR475507                   1447  ...             0               0
# ERR475506                    173  ...             0               0
# ...                          ...  ...           ...             ...
# SRR2143774                     0  ...             0               0
# SRR2143541                     0  ...             0               0
# SRR2143550                     0  ...             0               0
# SRR2143990                     0  ...             0               0
# SRR2143628                     0  ...             0               0
#
#                Papillibacter   Pantalinema   Jonquetella   Propionibacterium  \
# SampleID
# ERR475500                  0             0             0                   0
# Cancer7-2537               0             0             0                   0
# ERR475501                  0             0             0                   0
# ERR475507                  0             0             0                   0
# ERR475506                  0             0             0                   0
# ...                      ...           ...           ...                 ...
# SRR2143774                 0             0             0                   0
# SRR2143541                 0             0             0                   0
# SRR2143550                 0             0             0                   0
# SRR2143990                 0             0             0                   0
# SRR2143628                 0             0             0                   0
#
#                Devosia   FTLpost3   Achromobacter   Blastomonas
# SampleID
# ERR475500            0          0               0             0
# Cancer7-2537         0          0               0             0
# ERR475501            0          0               0             0
# ERR475507            0          0               0             0
# ERR475506            0          0               0             0
# ...                ...        ...             ...           ...
# SRR2143774           0          0               0             0
# SRR2143541           0          0               0             0
# SRR2143550           0          0               0             0
# SRR2143990           0          0               0             0
# SRR2143628           0          0               0             0
#
# [708 rows x 462 columns]

# %% [markdown]
# filtering of taxa with low prevalence:

# %%
def drop_almost_zero(df, percentage):


    column_cut_off = int(percentage/100*len(df)) 
    b = (df == 0).sum(axis='rows')
    df = df[ b[ b <= column_cut_off].index.values ]
    

    return df

# %%
genus_filtered=drop_almost_zero(genus,90)
genus_filtered
# Out:
#                Fusobacterium   Bacteroides   Prevotella   Sphingomonas  \
# SampleID
# ERR475500                  0          2651           11           8991
# Cancer7-2537          214716         13442           16              0
# ERR475501                  0        180089           25          36718
# ERR475507                  0         65835       151518          16385
# ERR475506                  0          1024          164         144878
# ...                      ...           ...          ...            ...
# SRR2143774                 0           528            0              0
# SRR2143541                 0          1257            0              0
# SRR2143550                 0          1253         1059              0
# SRR2143990                 0           312            0              0
# SRR2143628                 0           615            0              0
#
#                Blautia   Faecalibacterium  \
# SampleID
# ERR475500          736                242
# Cancer7-2537     23077                 37
# ERR475501         4312               1124
# ERR475507         4057              52951
# ERR475506       129257                340
# ...                ...                ...
# SRR2143774         999                202
# SRR2143541         495                141
# SRR2143550         240                238
# SRR2143990         548                 17
# SRR2143628         525                 48
#
#                [Eubacterium]_coprostanoligenes_group   Akkermansia  \
# SampleID
# ERR475500                                       3262         52978
# Cancer7-2537                                      64           533
# ERR475501                                         16             0
# ERR475507                                       1353          6781
# ERR475506                                       4787             0
# ...                                              ...           ...
# SRR2143774                                        13           837
# SRR2143541                                       122             0
# SRR2143550                                        73             0
# SRR2143990                                       215           393
# SRR2143628                                       101            74
#
#                Lachnoclostridium   Escherichia-Shigella  ...   Merdibacter  \
# SampleID                                                 ...
# ERR475500                    961                  27326  ...           107
# Cancer7-2537                2908                  49077  ...             0
# ERR475501                  70389                  15959  ...             0
# ERR475507                   1447                   2172  ...             6
# ERR475506                    173                     19  ...           131
# ...                          ...                    ...  ...           ...
# SRR2143774                     0                      0  ...             0
# SRR2143541                     0                      0  ...             0
# SRR2143550                     0                     10  ...             0
# SRR2143990                     0                     38  ...             0
# SRR2143628                     0                      0  ...             0
#
#                Adlercreutzia   Shuttleworthia   Anaerofustis   Atopobium  \
# SampleID
# ERR475500                  0               25              6           5
# Cancer7-2537               0                0              0           0
# ERR475501                  0                0              0           0
# ERR475507                  0                0              0           5
# ERR475506                  0                0              6           0
# ...                      ...              ...            ...         ...
# SRR2143774                 0                0              0           0
# SRR2143541                 0                0              0           0
# SRR2143550                 0                0              0           0
# SRR2143990                 0                0              4           0
# SRR2143628                 0                0              0           0
#
#                Holdemania   Methylobacterium-Methylorubrum   Gordonibacter  \
# SampleID
# ERR475500               0                                6               0
# Cancer7-2537           30                                0               0
# ERR475501               0                              101               0
# ERR475507              46                                0               0
# ERR475506               0                               30               0
# ...                   ...                              ...             ...
# SRR2143774              0                                0               0
# SRR2143541              0                                0               0
# SRR2143550              0                                0               0
# SRR2143990              0                                0               0
# SRR2143628              0                                0               0
#
#                Candidatus_Soleaferrea   GCA-900066755
# SampleID
# ERR475500                           0               0
# Cancer7-2537                        0               0
# ERR475501                           0             103
# ERR475507                           0               0
# ERR475506                           0               0
# ...                               ...             ...
# SRR2143774                          0               0
# SRR2143541                          0               0
# SRR2143550                          0               0
# SRR2143990                          0               0
# SRR2143628                          0               0
#
# [708 rows x 164 columns]

# %% [markdown]
# loading metadata information:

# %%
metadata=pd.read_csv( "metadata.csv",index_col=0)
metadata
# Out:
#                      SubjectID Diagnosis     Study Country   Age Gender BMI  \
# SampleID
# Adenoma1-2065    Adenoma1-2065   Adenoma  Zackular      CA  76      m    23
# Adenoma10-2757  Adenoma10-2757   Adenoma  Zackular      CA  37      m    24
# Adenoma11-2775  Adenoma11-2775   Adenoma  Zackular      CA  65      f    21
# Adenoma12-2799  Adenoma12-2799   Adenoma  Zackular      CA  82      m    36
# Adenoma13-2803  Adenoma13-2803   Adenoma  Zackular      CA  62      m    28
# ...                        ...       ...       ...     ...   ...    ...  ..
# SRR2144126             3535650   Adenoma    Baxter     USA    53      f  34
# SRR2144127             3537650    Normal    Baxter     USA    75      m  27
# SRR2144128             3551650   Adenoma    Baxter     USA    56      f  27
# SRR2144129             3561650    Normal    Baxter     USA    77      m  24
# SRR2144130             2915650   Adenoma    Baxter     USA    51      f  25
#
#                 Total_reads  Reads_after_QC  used_read_count_percentage  \
# SampleID
# Adenoma1-2065        139559          107534                       77.05
# Adenoma10-2757        69882           53194                       76.12
# Adenoma11-2775       116629           91060                       78.08
# Adenoma12-2799        71532           51092                       71.43
# Adenoma13-2803       146499          111419                       76.05
# ...                     ...             ...                         ...
# SRR2144126            41261           31732                       76.91
# SRR2144127            65890           54475                       82.68
# SRR2144128            48961           39779                       81.25
# SRR2144129            41095           33738                       82.10
# SRR2144130            45557           36018                       79.06
#
#                16S_Region    Seq_platform
# SampleID
# Adenoma1-2065          V4  Illumina MiSeq
# Adenoma10-2757         V4  Illumina MiSeq
# Adenoma11-2775         V4  Illumina MiSeq
# Adenoma12-2799         V4  Illumina MiSeq
# Adenoma13-2803         V4  Illumina MiSeq
# ...                   ...             ...
# SRR2144126             V4  Illumina MiSeq
# SRR2144127             V4  Illumina MiSeq
# SRR2144128             V4  Illumina MiSeq
# SRR2144129             V4  Illumina MiSeq
# SRR2144130             V4  Illumina MiSeq
#
# [708 rows x 12 columns]

# %% [markdown]
# centered log-ratio transformation (clr):

# %%
X_arr=np.array(genus_filtered)
for i in range(X_arr.shape[0]):
    
    X_arr[i][X_arr[i]==0]=1

# %%
X_temp=pd.DataFrame(X_arr,index=genus_filtered.index,columns=genus_filtered.columns)
X_clr=pd.DataFrame(clr(X_temp),index=genus_filtered.index,columns=genus_filtered.columns)

# %%
#changing columns names
regex = re.compile(r"\[|\]|<", re.IGNORECASE)
X_clr.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X_clr.columns.values]

# %% [markdown]
# preparing the dataset for the machine learning classification (adding Age, gender, BMI, Country)

# %%
for i in metadata.index:
    if metadata.loc[i,'Gender'].startswith("f"):
        metadata.at[i,'Gender']='f'
    elif metadata.loc[i,'Gender'].startswith("m"):
        metadata.at[i,'Gender']='m'

# %%
for i in metadata.index:
    if metadata.loc[i,'Gender'].startswith("F"):
        metadata.at[i,'Gender']='f'
    elif metadata.loc[i,'Gender'].startswith("M"):
        metadata.at[i,'Gender']='m'

# %%
for i in metadata.index:
    if metadata.loc[i,'BMI']=='#¡DIV/0!':
        metadata.at[i,'BMI']=np.nan

# %%
metadata['Age']=metadata['Age'].astype(int)
metadata['BMI']=metadata['BMI'].astype(float)

# %%
X_clr=X_clr.loc[metadata.index]

# %%
#adding BMI, age, gender
X_clr['BMI']=metadata.loc[X_clr.index]['BMI']
X_clr['Age']=metadata.loc[X_clr.index]['Age']
X_clr['Gender']=metadata.loc[X_clr.index]['Gender']

# %%
#one hot encoding
X_clr = pd.get_dummies(X_clr, columns = ['Gender'])
X_clr.drop(['Gender_f'],axis=1,inplace=True)

# %%
X_clr['Country']=metadata.loc[X_clr.index]['Country']

# %%
#one hot encoding
X_clr = pd.get_dummies(X_clr, columns = ['Country'])

# %%
#adding diagnosis
X_clr['Diagnosis']=metadata.loc[X_clr.index]['Diagnosis']

# %%
X_clr.to_csv('X_clr.csv')

# %%
np.unique(X_clr['Diagnosis'],return_counts=True)
# Out:
# (array(['Adenoma', 'Cancer', 'Large adenoma', 'Normal', 'Small adenoma'],
#        dtype=object),
#  array([228, 191,  13, 251,  25]))

# %%
#selecting only cancer and adenoma subjects
X_clr_adenoma=X_clr.loc[(X_clr['Diagnosis']=='Adenoma')]
X_clr_small_adenoma=X_clr.loc[(X_clr['Diagnosis']=='Small adenoma')]
X_clr_large_adenoma=X_clr.loc[(X_clr['Diagnosis']=='Large adenoma')]
X_clr_cancer=X_clr.loc[X_clr['Diagnosis']=='Cancer']

# %% [markdown]
# final dataset

# %%
df=pd.concat([X_clr_adenoma,X_clr_small_adenoma,X_clr_large_adenoma,X_clr_cancer]).sample(frac=1,random_state=5)
df
# Out:
#                 Fusobacterium   Bacteroides   Prevotella   Sphingomonas  \
# SampleID
# SRR2143615          -1.486105      4.687681    -1.486105      -1.486105
# SRR2143547          -2.345212      5.676373    -2.345212      -2.345212
# Cancer24-2727       -1.052114      6.289693    -0.541289      -2.843874
# ERR475530           -2.683090      7.205182     4.905740       4.228657
# Cancer21-2671        5.535763      8.052574    -2.234882      -2.234882
# ...                       ...           ...          ...            ...
# SRR2143784          -1.595084      6.719013    -1.595084      -1.595084
# SRR2143752          -2.897568      6.511377     3.453318      -2.897568
# SRR2143952          -1.374877      6.215470    -1.374877      -1.374877
# SRR2144021          -1.191868      3.471572    -1.191868      -1.191868
# SRR2143669          -3.209010      7.977783    -0.569953      -3.209010
#
#                 Blautia   Faecalibacterium  \
# SampleID
# SRR2143615     7.144060           5.064976
# SRR2143547     6.429720           3.944504
# Cancer24-2727  6.363462           5.486025
# ERR475530      5.665685           2.906030
# Cancer21-2671  2.390091           1.549307
# ...                 ...                ...
# SRR2143784     5.787040           5.172259
# SRR2143752     5.657114           5.565802
# SRR2143952     6.347358           6.046899
# SRR2144021     8.240015           5.977482
# SRR2143669     5.808837           5.200820
#
#                 _Eubacterium__coprostanoligenes_group   Akkermansia  \
# SampleID
# SRR2143615                                   4.123367      4.946835
# SRR2143547                                   3.737007      6.546987
# Cancer24-2727                                3.215249      1.345781
# ERR475530                                    4.494311      4.199348
# Cancer21-2671                                3.237389      6.582712
# ...                                               ...           ...
# SRR2143784                                   6.615040      1.806113
# SRR2143752                                   3.938691      1.034258
# SRR2143952                                   3.976981      2.556949
# SRR2144021                                  -1.191868      1.752571
# SRR2143669                                   5.431108      5.005996
#
#                 Lachnoclostridium   Escherichia-Shigella  ...   Gordonibacter  \
# SampleID                                                  ...
# SRR2143615              -1.486105               1.286484  ...        1.649390
# SRR2143547              -2.345212               0.950625  ...       -2.345212
# Cancer24-2727            1.330513               2.205982  ...       -0.071285
# ERR475530                4.955349               2.320856  ...       -3.376237
# Cancer21-2671            4.900805               3.298507  ...       -2.234882
# ...                           ...                    ...  ...             ...
# SRR2143784               4.847456               0.969865  ...       -1.595084
# SRR2143752               2.278582               3.209455  ...       -1.105808
# SRR2143952               2.516944               2.955857  ...       -1.374877
# SRR2144021               0.599892               1.852655  ...       -1.191868
# SRR2143669               2.769875               3.922688  ...        0.086826
#
#                 Candidatus_Soleaferrea   GCA-900066755   BMI  Age  Gender_m  \
# SampleID
# SRR2143615                   -1.486105       -1.486105  24.0   67     False
# SRR2143547                   -2.345212       -2.345212  30.0   69     False
# Cancer24-2727                -1.457580       -2.843874  33.0   48      True
# ERR475530                    -3.376237       -0.543024  23.0   78     False
# Cancer21-2671                -2.234882       -2.234882  33.0   60      True
# ...                                ...             ...   ...  ...       ...
# SRR2143784                   -1.595084       -1.595084  31.0   78      True
# SRR2143752                   -2.897568       -2.897568  31.0   69      True
# SRR2143952                   -1.374877       -1.374877  23.0   81     False
# SRR2144021                   -1.191868       -1.191868  21.0   61     False
# SRR2143669                    0.619631       -0.724104  30.0   80     False
#
#                Country_CA  Country_FRA  Country_USA      Diagnosis
# SampleID
# SRR2143615          False        False         True        Adenoma
# SRR2143547          False        False         True        Adenoma
# Cancer24-2727       False        False         True         Cancer
# ERR475530           False         True        False  Large adenoma
# Cancer21-2671       False        False         True         Cancer
# ...                   ...          ...          ...            ...
# SRR2143784          False        False         True         Cancer
# SRR2143752          False        False         True        Adenoma
# SRR2143952          False        False         True        Adenoma
# SRR2144021          False        False         True        Adenoma
# SRR2143669          False        False         True         Cancer
#
# [457 rows x 171 columns]

# %%
df.to_csv('df.csv')
